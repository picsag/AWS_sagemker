# %% [markdown]
# # TensorFlow script mode training and serving
# ###  Modified From:
# #### Sagemaker Python SDK Examples: tensorflow_script_mode_training_and_serving.ipynb
# https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/tensorflow_script_mode_training_and_serving/tensorflow_script_mode_training_and_serving.ipynb
#
# Following modifications were made:
# 1. Incorporated scripts for local mode hosting
# 2. Added Train and Test Channels
# 3. Visualize results (confusion matrix and reports)
# 4. Added steps to deploy using model artifacts stored in S3
# 5. Iris model training
#
# Script mode is a training script format for TensorFlow that lets you execute any TensorFlow training script in SageMaker with minimal modification. The [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) handles transferring your script to a SageMaker training instance. On the training instance, SageMaker's native TensorFlow support sets up training-related environment variables and executes your training script. In this tutorial, we use the SageMaker Python SDK to launch a training job and deploy the trained model.
#
# Script mode supports training with a Python script, a Python module, or a shell script.

# %% [markdown]
# # Set up the environment
#
# Let's start by setting up the environment:

# %% [markdown]
# ### Local Mode Execution - requires docker compose configured
# #### The below setup script is from AWS SageMaker Python SDK Examples : tf-eager-sm-scriptmode.ipynb

# %%
# !/bin/bash ./setup.sh
# Out:
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %%
import os
import sagemaker
from sagemaker import get_execution_role
import pandas as pd
import numpy as np

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %% [markdown]
# ## Training Data

# %%
column_list_file = '../data/iris/iris_train_column_list.txt'
train_file = '../data/iris_train.csv'
test_file = '../data/iris_validation.csv'

columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
# Specify your bucket name
bucket_name = 'radcv-ml-sagemaker'

training_folder = r'iris/train_tf'
test_folder = r'iris/test_tf'
model_folder = r'iris/model_tf/'

training_data_uri = r's3://' + bucket_name + r'/' + training_folder
testing_data_uri = r's3://' + bucket_name + r'/' + test_folder
model_data_uri = r's3://' + bucket_name + r'/' + model_folder

# %%
training_data_uri,testing_data_uri,model_data_uri
# Out:
# ('s3://radcv-ml-sagemaker/iris/train_tf',
#  's3://radcv-ml-sagemaker/iris/test_tf',
#  's3://radcv-ml-sagemaker/iris/model_tf/')

# %%
sagemaker_session.upload_data(train_file,
                              bucket=bucket_name, 
                              key_prefix=training_folder)
# Out:
# 's3://radcv-ml-sagemaker/iris/train_tf/iris_train.csv'

# %%
sagemaker_session.upload_data(test_file, 
                              bucket=bucket_name, 
                              key_prefix=test_folder)
# Out:
# 's3://radcv-ml-sagemaker/iris/test_tf/iris_validation.csv'

# %% [markdown]
# # Construct a script for distributed training
#
# This tutorial's training script was adapted from TensorFlow's official [CNN MNIST example](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/tutorials/layers/cnn_mnist.py). We have modified it to handle the ``model_dir`` parameter passed in by SageMaker. This is an S3 path which can be used for data sharing during distributed training and checkpointing and/or model persistence. We have also added an argument-parsing function to handle processing training-related variables.
#
# At the end of the training job we have added a step to export the trained model to the path stored in the environment variable ``SM_MODEL_DIR``, which always points to ``/opt/ml/model``. This is critical because SageMaker uploads all the model artifacts in this folder to S3 at end of training.
#
# Here is the entire script:

# %%
# !pygmentize 'tensorflow_iris.py'
# Out:
# # Copyright 2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.import tensorflow as tf
#
# # Modified to train Iris model with early stopping - CL
#
# import os
# import numpy as np
# import json
# import pandas as pd
# # Set random seed
# np.random.seed(0)
#
# import tensorflow as tf
# import argparse
#
#
# def model(x_train, y_train, x_test, y_test):
#     model = tf.keras.models.Sequential()
#     model.add(tf.keras.layers.Dense(32, activation=tf.nn.relu, input_dim=x_train.shape[1]))
#     model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))
#
#     model.compile(optimizer='rmsprop',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#
#     early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
#
#     model.fit(x_train, y_train,
#               epochs=300,
#               batch_size=32,
#               validation_data=(x_test,y_test),
#               callbacks=[early_stopping])
#
#     return model
#
#
# def _load_data(file_path, channel):
#     # Take the set of files and read them all into a single pandas dataframe
#     input_files = [ os.path.join(file_path, file) for file in os.listdir(file_path) ]
#     if len(input_files) == 0:
#         raise ValueError(('There are no files in {}.\n' +
#                           'This usually indicates that the channel ({}) was incorrectly specified,\n' +
#                           'the data specification in S3 was incorrectly specified or the role specified\n' +
#                           'does not have permission to access the data.').format(file_path, channel))
#
#     raw_data = [ pd.read_csv(file, header=None, engine="python") for file in input_files ]
#     df = pd.concat(raw_data)
#
#     features = df.iloc[:,1:].values
#     label = df.iloc[:,0].values
#     return features, label
#
#
# def _parse_args():
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument('--model_dir', type=str)
#     parser.add_argument('--sm-model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
#     parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAINING'))
#     parser.add_argument('--test', type=str, default=os.environ.get('SM_CHANNEL_TESTING'))
#
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ.get('SM_HOSTS')))
#     parser.add_argument('--current-host', type=str, default=os.environ.get('SM_CURRENT_HOST'))
#
#     return parser.parse_known_args()
#
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_data(args.train,'train')
#     eval_data, eval_labels = _load_data(args.test,'test')
#
#     classifier = model(train_data, train_labels, eval_data, eval_labels)
#
#     if args.current_host == args.hosts[0]:
#         # save model to an S3 directory with version number '00000001'
#         classifier.save(os.path.join(args.sm_model_dir, '000000001'), 'my_model.h5')

# %% [markdown]
# # Create a training job using the `TensorFlow` estimator
#
# The `sagemaker.tensorflow.TensorFlow` estimator handles locating the script mode container, uploading your script to a S3 location and creating a SageMaker training job. Let's call out a couple important parameters here:
#
# * `py_version` is set to `'py3'` to indicate that we are using script mode since legacy mode supports only Python 2. Though Python 2 will be deprecated soon, you can use script mode with Python 2 by setting `py_version` to `'py2'` and `script_mode` to `True`.
#
# * `distributions` is used to configure the distributed training setup. It's required only if you are doing distributed training either across a cluster of instances or across multiple GPUs. Here we are using parameter servers as the distributed training schema. SageMaker training jobs run on homogeneous clusters. To make parameter server more performant in the SageMaker setup, we run a parameter server on every instance in the cluster, so there is no need to specify the number of parameter servers to launch. Script mode also supports distributed training with [Horovod](https://github.com/horovod/horovod). You can find the full documentation on how to configure `distributions` [here](https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#distributed-training).

# %%
from sagemaker.tensorflow import TensorFlow

# %% [markdown]
# You can also initiate an estimator to train with TensorFlow 2.1 script. The only things that you will need to change are the script name and ``framewotk_version``

# %%
#instance_type='ml.m5.xlarge'
instance_type='local'

# %%
# Reference: https://sagemaker.readthedocs.io/en/stable/v2.html

# SDK 2.x version does not require train prefix for instance count and type
estimator = TensorFlow(entry_point='tensorflow_iris.py',
                       role=role,
                       instance_count=1,
                       instance_type=instance_type,
                       framework_version='2.6.0',
                       py_version='py38',
                       output_path=model_data_uri,
                       base_job_name='tf-iris',                       
                       distributions={'parameter_server': {'enabled': False}})
# Out:
# distributions has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Calling ``fit``
#
# To start a training job, we call `estimator.fit(training_data_uri)`.
#
# An S3 location is used here as the input. `fit` creates a default channel named `'training'`, which points to this S3 location. In the training script we can then access the training data from the location stored in `SM_CHANNEL_TRAINING`. `fit` accepts a couple other types of input as well. See the API doc [here](https://sagemaker.readthedocs.io/en/stable/estimators.html#sagemaker.estimator.EstimatorBase.fit) for details.
#
# When training starts, the TensorFlow container executes mnist.py, passing `hyperparameters` and `model_dir` from the estimator as script arguments. Because we didn't define either in this example, no hyperparameters are passed, and `model_dir` defaults to `s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>`, so the script execution is as follows:
# ```bash
# python mnist.py --model_dir s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>
# ```
# When training is complete, the training job will upload the saved model for TensorFlow serving.

# %% [markdown]
# Calling fit to train a model with TensorFlow 2.1 scroipt.

# %%
estimator.fit({'training':training_data_uri,'testing':testing_data_uri})
# Out:
# Creating 9p81kxe8ft-algo-1-ki1dh ...
# Creating 9p81kxe8ft-algo-1-ki1dh ... done
# Attaching to 9p81kxe8ft-algo-1-ki1dh
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:54.514484: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:54.514709: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:54.549484: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:55,965 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:55,975 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:56,332 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:56,350 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:56,370 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:56,380 sagemaker-training-toolkit INFO     Invoking user script
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | Training Env:
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | {
# 9p81kxe8ft-algo-1-ki1dh |     "additional_framework_parameters": {
# 9p81kxe8ft-algo-1-ki1dh |         "sagemaker_parameter_server_enabled": false
# 9p81kxe8ft-algo-1-ki1dh |     },
# 9p81kxe8ft-algo-1-ki1dh |     "channel_input_dirs": {
# 9p81kxe8ft-algo-1-ki1dh |         "training": "/opt/ml/input/data/training",
# 9p81kxe8ft-algo-1-ki1dh |         "testing": "/opt/ml/input/data/testing"
# 9p81kxe8ft-algo-1-ki1dh |     },
# 9p81kxe8ft-algo-1-ki1dh |     "current_host": "algo-1-ki1dh",
# 9p81kxe8ft-algo-1-ki1dh |     "framework_module": "sagemaker_tensorflow_container.training:main",
# 9p81kxe8ft-algo-1-ki1dh |     "hosts": [
# 9p81kxe8ft-algo-1-ki1dh |         "algo-1-ki1dh"
# 9p81kxe8ft-algo-1-ki1dh |     ],
# 9p81kxe8ft-algo-1-ki1dh |     "hyperparameters": {
# 9p81kxe8ft-algo-1-ki1dh |         "model_dir": "s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model"
# 9p81kxe8ft-algo-1-ki1dh |     },
# 9p81kxe8ft-algo-1-ki1dh |     "input_config_dir": "/opt/ml/input/config",
# 9p81kxe8ft-algo-1-ki1dh |     "input_data_config": {
# 9p81kxe8ft-algo-1-ki1dh |         "training": {
# 9p81kxe8ft-algo-1-ki1dh |             "TrainingInputMode": "File"
# 9p81kxe8ft-algo-1-ki1dh |         },
# 9p81kxe8ft-algo-1-ki1dh |         "testing": {
# 9p81kxe8ft-algo-1-ki1dh |             "TrainingInputMode": "File"
# 9p81kxe8ft-algo-1-ki1dh |         }
# 9p81kxe8ft-algo-1-ki1dh |     },
# 9p81kxe8ft-algo-1-ki1dh |     "input_dir": "/opt/ml/input",
# 9p81kxe8ft-algo-1-ki1dh |     "is_master": true,
# 9p81kxe8ft-algo-1-ki1dh |     "job_name": "tf-iris-2022-08-02-14-26-50-640",
# 9p81kxe8ft-algo-1-ki1dh |     "log_level": 20,
# 9p81kxe8ft-algo-1-ki1dh |     "master_hostname": "algo-1-ki1dh",
# 9p81kxe8ft-algo-1-ki1dh |     "model_dir": "/opt/ml/model",
# 9p81kxe8ft-algo-1-ki1dh |     "module_dir": "s3://radcv-ml-sagemaker/tf-iris-2022-08-02-14-26-50-640/source/sourcedir.tar.gz",
# 9p81kxe8ft-algo-1-ki1dh |     "module_name": "tensorflow_iris",
# 9p81kxe8ft-algo-1-ki1dh |     "network_interface_name": "eth0",
# 9p81kxe8ft-algo-1-ki1dh |     "num_cpus": 4,
# 9p81kxe8ft-algo-1-ki1dh |     "num_gpus": 0,
# 9p81kxe8ft-algo-1-ki1dh |     "output_data_dir": "/opt/ml/output/data",
# 9p81kxe8ft-algo-1-ki1dh |     "output_dir": "/opt/ml/output",
# 9p81kxe8ft-algo-1-ki1dh |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 9p81kxe8ft-algo-1-ki1dh |     "resource_config": {
# 9p81kxe8ft-algo-1-ki1dh |         "current_host": "algo-1-ki1dh",
# 9p81kxe8ft-algo-1-ki1dh |         "hosts": [
# 9p81kxe8ft-algo-1-ki1dh |             "algo-1-ki1dh"
# 9p81kxe8ft-algo-1-ki1dh |         ]
# 9p81kxe8ft-algo-1-ki1dh |     },
# 9p81kxe8ft-algo-1-ki1dh |     "user_entry_point": "tensorflow_iris.py"
# 9p81kxe8ft-algo-1-ki1dh | }
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | Environment variables:
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | SM_HOSTS=["algo-1-ki1dh"]
# 9p81kxe8ft-algo-1-ki1dh | SM_NETWORK_INTERFACE_NAME=eth0
# 9p81kxe8ft-algo-1-ki1dh | SM_HPS={"model_dir":"s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model"}
# 9p81kxe8ft-algo-1-ki1dh | SM_USER_ENTRY_POINT=tensorflow_iris.py
# 9p81kxe8ft-algo-1-ki1dh | SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":false}
# 9p81kxe8ft-algo-1-ki1dh | SM_RESOURCE_CONFIG={"current_host":"algo-1-ki1dh","hosts":["algo-1-ki1dh"]}
# 9p81kxe8ft-algo-1-ki1dh | SM_INPUT_DATA_CONFIG={"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# 9p81kxe8ft-algo-1-ki1dh | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 9p81kxe8ft-algo-1-ki1dh | SM_CHANNELS=["testing","training"]
# 9p81kxe8ft-algo-1-ki1dh | SM_CURRENT_HOST=algo-1-ki1dh
# 9p81kxe8ft-algo-1-ki1dh | SM_MODULE_NAME=tensorflow_iris
# 9p81kxe8ft-algo-1-ki1dh | SM_LOG_LEVEL=20
# 9p81kxe8ft-algo-1-ki1dh | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# 9p81kxe8ft-algo-1-ki1dh | SM_INPUT_DIR=/opt/ml/input
# 9p81kxe8ft-algo-1-ki1dh | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 9p81kxe8ft-algo-1-ki1dh | SM_OUTPUT_DIR=/opt/ml/output
# 9p81kxe8ft-algo-1-ki1dh | SM_NUM_CPUS=4
# 9p81kxe8ft-algo-1-ki1dh | SM_NUM_GPUS=0
# 9p81kxe8ft-algo-1-ki1dh | SM_MODEL_DIR=/opt/ml/model
# 9p81kxe8ft-algo-1-ki1dh | SM_MODULE_DIR=s3://radcv-ml-sagemaker/tf-iris-2022-08-02-14-26-50-640/source/sourcedir.tar.gz
# 9p81kxe8ft-algo-1-ki1dh | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":false},"channel_input_dirs":{"testing":"/opt/ml/input/data/testing","training":"/opt/ml/input/data/training"},"current_host":"algo-1-ki1dh","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-ki1dh"],"hyperparameters":{"model_dir":"s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-iris-2022-08-02-14-26-50-640","log_level":20,"master_hostname":"algo-1-ki1dh","model_dir":"/opt/ml/model","module_dir":"s3://radcv-ml-sagemaker/tf-iris-2022-08-02-14-26-50-640/source/sourcedir.tar.gz","module_name":"tensorflow_iris","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ki1dh","hosts":["algo-1-ki1dh"]},"user_entry_point":"tensorflow_iris.py"}
# 9p81kxe8ft-algo-1-ki1dh | SM_USER_ARGS=["--model_dir","s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model"]
# 9p81kxe8ft-algo-1-ki1dh | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 9p81kxe8ft-algo-1-ki1dh | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# 9p81kxe8ft-algo-1-ki1dh | SM_CHANNEL_TESTING=/opt/ml/input/data/testing
# 9p81kxe8ft-algo-1-ki1dh | SM_HP_MODEL_DIR=s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model
# 9p81kxe8ft-algo-1-ki1dh | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python38.zip:/usr/local/lib/python3.8:/usr/local/lib/python3.8/lib-dynload:/usr/local/lib/python3.8/site-packages
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | Invoking script with the following command:
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | /usr/local/bin/python3.8 tensorflow_iris.py --model_dir s3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-25-02-200/model
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh |
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:57.104087: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:57.104238: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:26:57.131991: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 9p81kxe8ft-algo-1-ki1dh | Epoch 1/300
# 9p81kxe8ft-algo-1-ki1dh | Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# 9p81kxe8ft-algo-1-ki1dh | If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# 9p81kxe8ft-algo-1-ki1dh | Warning! MPI libs are missing, but python applications are still avaiable.
# 9p81kxe8ft-algo-1-ki1dh | [2022-08-02 14:26:59.154 dbe0f0ecdc95:30 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# 9p81kxe8ft-algo-1-ki1dh | [2022-08-02 14:26:59.316 dbe0f0ecdc95:30 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# 9p81kxe8ft-algo-1-ki1dh | 1/4 [======>.......................]
# 9p81kxe8ft-algo-1-ki1dh | - ETA: 2s - loss: 2.4397 - accuracy: 0.4062
# 4/4 [==============================]
# 9p81kxe8ft-algo-1-ki1dh | -
W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 9p81kxe8ft-algo-1-ki1dh | INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# 9p81kxe8ft-algo-1-ki1dh | INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# 9p81kxe8ft-algo-1-ki1dh | 2022-08-02 14:27:11,702 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 9p81kxe8ft-algo-1-ki1dh exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
estimator.latest_training_job.job_name
# Out:
# 'tf-iris-2022-08-02-14-26-50-640'

# %%
estimator.model_data
# Out:
# 's3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-26-50-640/model.tar.gz'

# %% [markdown]
# # Deploy the trained model to an endpoint
#
# The `deploy()` method creates a SageMaker model, which is then deployed to an endpoint to serve prediction requests in real time. We will use the TensorFlow Serving container for the endpoint, because we trained with script mode. This serving container runs an implementation of a web server that is compatible with SageMaker hosting protocol. The [Using your own inference code]() document explains how SageMaker runs inference containers.

# %% [markdown]
# Deployed the trained TensorFlow 2.1 model to an endpoint.

# %%
predictor = estimator.deploy(initial_instance_count=1, instance_type=instance_type)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Attaching to iqvz3m4se2-algo-1-ul4kh
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:PYTHON SERVICE: False
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:starting services
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:using default model name: model
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:tensorflow serving model config:
# iqvz3m4se2-algo-1-ul4kh | model_config_list: {
# iqvz3m4se2-algo-1-ul4kh |   config: {
# iqvz3m4se2-algo-1-ul4kh |     name: 'model'
# iqvz3m4se2-algo-1-ul4kh |     base_path: '/opt/ml/model'
# iqvz3m4se2-algo-1-ul4kh |     model_platform: 'tensorflow'
# iqvz3m4se2-algo-1-ul4kh |     model_version_policy: {
# iqvz3m4se2-algo-1-ul4kh |       specific: {
# iqvz3m4se2-algo-1-ul4kh |         versions: 1
# iqvz3m4se2-algo-1-ul4kh |       }
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |   }
# iqvz3m4se2-algo-1-ul4kh | }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:tensorflow version info:
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:51.587585: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:51.587727: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# iqvz3m4se2-algo-1-ul4kh | TensorFlow ModelServer: 2.6.0-rc2+dev.sha.dca3641
# iqvz3m4se2-algo-1-ul4kh | TensorFlow Library: 2.6.0
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:tensorflow serving command: tensorflow_model_server --port=9000 --rest_api_port=8501 --model_config_file=/sagemaker/model-config.cfg --max_num_load_retries=0
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:started tensorflow serving (pid: 17)
# iqvz3m4se2-algo-1-ul4kh | INFO:tfs_utils:Trying to connect with model server: http://localhost:8501/v1/models/model
# iqvz3m4se2-algo-1-ul4kh | WARNING:urllib3.connectionpool:Retrying (Retry(total=8, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd7eefcffd0>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.157526: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.157652: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.160780: I tensorflow_serving/model_servers/server_core.cc:465] Adding/updating models.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.160822: I tensorflow_serving/model_servers/server_core.cc:591]  (Re-)adding model: model
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.261243: I tensorflow_serving/util/retrier.cc:46] Retrying of Reserving resources for servable: {name: model version: 1} exhausted max_num_retries: 0
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.261301: I tensorflow_serving/core/basic_manager.cc:740] Successfully reserved resources to load servable {name: model version: 1}
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.261314: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.261334: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.261433: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:38] Reading SavedModel from: /opt/ml/model/000000001
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.263376: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:90] Reading meta graph with tags { serve }
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.263410: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /opt/ml/model/000000001
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.263519: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# iqvz3m4se2-algo-1-ul4kh | To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.265066: I external/org_tensorflow/tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.307702: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:211] Restoring SavedModel bundle.
# iqvz3m4se2-algo-1-ul4kh | WARNING:urllib3.connectionpool:Retrying (Retry(total=7, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd7eeff5250>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.352256: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:195] Running initialization op on SavedModel bundle at path: /opt/ml/model/000000001
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.359449: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:283] SavedModel load for tags { serve }; Status: success: OK. Took 98010 microseconds.
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.360432: I tensorflow_serving/servables/tensorflow/saved_model_warmup_util.cc:59] No warmup data file found at /opt/ml/model/000000001/assets.extra/tf_serving_warmup_requests
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.361178: I tensorflow_serving/util/retrier.cc:46] Retrying of Loading servable: {name: model version: 1} exhausted max_num_retries: 0
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.361202: I tensorflow_serving/core/loader_harness.cc:87] Successfully loaded servable version {name: model version: 1}
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.364908: I tensorflow_serving/model_servers/server_core.cc:486] Finished adding/updating models
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.365106: I tensorflow_serving/model_servers/server.cc:133] Using InsecureServerCredentials
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.365169: I tensorflow_serving/model_servers/server.cc:383] Profiler service is enabled
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.367337: I tensorflow_serving/model_servers/server.cc:409] Running gRPC ModelServer at 0.0.0.0:9000 ...
# iqvz3m4se2-algo-1-ul4kh | [warn] getaddrinfo: address family for nodename not supported
# iqvz3m4se2-algo-1-ul4kh | 2022-08-02 14:28:52.368550: I tensorflow_serving/model_servers/server.cc:430] Exporting HTTP/REST API at:localhost:8501 ...
# iqvz3m4se2-algo-1-ul4kh | [evhttp_server.cc : 245] NET_LOG: Entering the event loop ...
# iqvz3m4se2-algo-1-ul4kh | WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd7eeff5460>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# iqvz3m4se2-algo-1-ul4kh | INFO:tfs_utils:<Response [200]>
# iqvz3m4se2-algo-1-ul4kh | INFO:tfs_utils:model: http://localhost:8501/v1/models/model is available now
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:nginx config:
# iqvz3m4se2-algo-1-ul4kh | load_module modules/ngx_http_js_module.so;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | worker_processes auto;
# iqvz3m4se2-algo-1-ul4kh | daemon off;
# iqvz3m4se2-algo-1-ul4kh | pid /tmp/nginx.pid;
# iqvz3m4se2-algo-1-ul4kh | error_log  /dev/stderr info;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | worker_rlimit_nofile 4096;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | events {
# iqvz3m4se2-algo-1-ul4kh |   worker_connections 2048;
# iqvz3m4se2-algo-1-ul4kh | }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | http {
# iqvz3m4se2-algo-1-ul4kh |   include /etc/nginx/mime.types;
# iqvz3m4se2-algo-1-ul4kh |   default_type application/json;
# iqvz3m4se2-algo-1-ul4kh |   access_log /dev/stdout combined;
# iqvz3m4se2-algo-1-ul4kh |   js_include tensorflow-serving.js;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |   upstream tfs_upstream {
# iqvz3m4se2-algo-1-ul4kh |     server localhost:8501;
# iqvz3m4se2-algo-1-ul4kh |   }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |   upstream gunicorn_upstream {
# iqvz3m4se2-algo-1-ul4kh |     server unix:/tmp/gunicorn.sock fail_timeout=1;
# iqvz3m4se2-algo-1-ul4kh |   }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |   server {
# iqvz3m4se2-algo-1-ul4kh |     listen 8080 deferred;
# iqvz3m4se2-algo-1-ul4kh |     client_max_body_size 0;
# iqvz3m4se2-algo-1-ul4kh |     client_body_buffer_size 100m;
# iqvz3m4se2-algo-1-ul4kh |     subrequest_output_buffer_size 100m;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     set $tfs_version 2.6;
# iqvz3m4se2-algo-1-ul4kh |     set $default_tfs_model model;
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     location /tfs {
# iqvz3m4se2-algo-1-ul4kh |         rewrite ^/tfs/(.*) /$1  break;
# iqvz3m4se2-algo-1-ul4kh |         proxy_redirect off;
# iqvz3m4se2-algo-1-ul4kh |         proxy_pass_request_headers off;
# iqvz3m4se2-algo-1-ul4kh |         proxy_set_header Content-Type 'application/json';
# iqvz3m4se2-algo-1-ul4kh |         proxy_set_header Accept 'application/json';
# iqvz3m4se2-algo-1-ul4kh |         proxy_pass http://tfs_upstream;
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     location /ping {
# iqvz3m4se2-algo-1-ul4kh |         js_content ping;
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     location /invocations {
# iqvz3m4se2-algo-1-ul4kh |         js_content invocations;
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     location /models {
# iqvz3m4se2-algo-1-ul4kh |         proxy_pass http://gunicorn_upstream/models;
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     location / {
# iqvz3m4se2-algo-1-ul4kh |         return 404 '{"error": "Not Found"}';
# iqvz3m4se2-algo-1-ul4kh |     }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |     keepalive_timeout 3;
# iqvz3m4se2-algo-1-ul4kh |   }
# iqvz3m4se2-algo-1-ul4kh | }
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh |
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:nginx version info:
# iqvz3m4se2-algo-1-ul4kh | nginx version: nginx/1.20.1
# iqvz3m4se2-algo-1-ul4kh | built by gcc 9.3.0 (Ubuntu 9.3.0-10ubuntu2)
# iqvz3m4se2-algo-1-ul4kh | built with OpenSSL 1.1.1f  31 Mar 2020
# iqvz3m4se2-algo-1-ul4kh | TLS SNI support enabled
# iqvz3m4se2-algo-1-ul4kh | configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fdebug-prefix-map=/data/builder/debuild/nginx-1.20.1/debian/debuild-base/nginx-1.20.1=. -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# iqvz3m4se2-algo-1-ul4kh | INFO:__main__:started nginx (pid: 73)
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: using the "epoll" event method
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: nginx/1.20.1
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: built by gcc 9.3.0 (Ubuntu 9.3.0-10ubuntu2)
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: OS: Linux 4.14.252-131.483.amzn1.x86_64
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: getrlimit(RLIMIT_NOFILE): 32768:65536
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: start worker processes
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: start worker process 74
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: start worker process 75
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: start worker process 76
# iqvz3m4se2-algo-1-ul4kh | 2022/08/02 14:28:52 [notice] 73#73: start worker process 77
# !iqvz3m4se2-algo-1-ul4kh | 172.18.0.1 - - [02/Aug/2022:14:28:56 +0000] "GET /ping HTTP/1.1" 200 0 "-" "python-urllib3/1.26.8"

# %% [markdown]
# # Invoke the endpoint
#
# Let's download the training data and use that as input for inference.

# %% [markdown]
# Examine the prediction result from the TensorFlow 2.1 model.

# %%
df = pd.read_csv(test_file, names=columns)

# %%
df.head()
# Out:
#    encoded_class  sepal_length  sepal_width  petal_length  petal_width
# 0              1           5.8          2.7           4.1          1.0
# 1              0           4.8          3.4           1.6          0.2
# 2              1           6.0          2.2           4.0          1.0
# 3              2           6.4          3.1           5.5          1.8
# 4              2           6.7          2.5           5.8          1.8

# %%
X_test = df.iloc[:,1:].values
print(X_test[:5])
# Out:
# [[5.8 2.7 4.1 1. ]
#  [4.8 3.4 1.6 0.2]
#  [6.  2.2 4.  1. ]
#  [6.4 3.1 5.5 1.8]
#  [6.7 2.5 5.8 1.8]]

# %%
result = predictor.predict(X_test)
# Out:
# iqvz3m4se2-algo-1-ul4kh | 172.18.0.1 - - [02/Aug/2022:14:29:50 +0000] "POST /invocations HTTP/1.1" 200 1982 "-" "python-urllib3/1.26.8"

# %%
result =  result['predictions']

# %%
result[:5]
# Out:
# [[0.0159433, 0.863972843, 0.120083801],
#  [0.987494886, 0.0124852769, 1.99404385e-05],
#  [0.00683279242, 0.843511641, 0.149655521],
#  [9.16040372e-05, 0.399594814, 0.600313604],
#  [9.18628e-06, 0.234145746, 0.76584512]]

# %%
df['predicted_class'] = np.argmax(result,axis=1)

# %%
df.head()
# Out:
#    encoded_class  sepal_length  sepal_width  petal_length  petal_width  \
# 0              1           5.8          2.7           4.1          1.0
# 1              0           4.8          3.4           1.6          0.2
# 2              1           6.0          2.2           4.0          1.0
# 3              2           6.4          3.1           5.5          1.8
# 4              2           6.7          2.5           5.8          1.8
#
#    predicted_class
# 0                1
# 1                0
# 2                1
# 3                2
# 4                2

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import itertools

# %%
# Encode Class Labels to integers
# Labeled Classes
labels=[0,1,2]
classes = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# <h2>Confusion Matrix</h2>
# Confusion Matrix is a table that summarizes performance of classification model.<br><br>

# %%
# Reference: 
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
    #    print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(df['encoded_class'],
                              df['predicted_class'],labels=labels)

# %%
cnf_matrix
# Out:
# array([[16,  0,  0],
#        [ 0, 10,  1],
#        [ 0,  1, 17]])

# %%
# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=classes,
                      title='Confusion matrix - Count')

# %%
# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=classes,
                      title='Confusion matrix - Count',normalize=True)

# %%
print(classification_report(
    df['encoded_class'],
    df['predicted_class'],
    labels=labels,
    target_names=classes))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.91      0.91      0.91        11
#  Iris-virginica       0.94      0.94      0.94        18
#
#        accuracy                           0.96        45
#       macro avg       0.95      0.95      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# # Delete the endpoint
#
# Let's delete the endpoint we just created to prevent incurring any extra costs.

# %% [markdown]
# Delete the TensorFlow 2.1 endpoint as well.

# %%
# SDK 2
predictor.delete_endpoint()
# Out:
# Gracefully stopping... (press Ctrl+C again to force)

# %% [markdown]
# # Deploy model using artifacts
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#deploy-to-a-sagemaker-endpoint

# %%
from sagemaker.tensorflow.model import TensorFlowModel

# %%
model_data = estimator.model_data

# %%
model_data
# Out:
# 's3://radcv-ml-sagemaker/iris/model_tf/tf-iris-2022-08-02-14-26-50-640/model.tar.gz'

# %%
model = TensorFlowModel(model_data=model_data, role=role,framework_version='2.6.0')

# %%
predictor = model.deploy(initial_instance_count=1, instance_type=instance_type)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Attaching to 2zgrtnfxpq-algo-1-t98o0
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:PYTHON SERVICE: False
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:starting services
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:using default model name: model
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:tensorflow serving model config:
# 2zgrtnfxpq-algo-1-t98o0 | model_config_list: {
# 2zgrtnfxpq-algo-1-t98o0 |   config: {
# 2zgrtnfxpq-algo-1-t98o0 |     name: 'model'
# 2zgrtnfxpq-algo-1-t98o0 |     base_path: '/opt/ml/model'
# 2zgrtnfxpq-algo-1-t98o0 |     model_platform: 'tensorflow'
# 2zgrtnfxpq-algo-1-t98o0 |     model_version_policy: {
# 2zgrtnfxpq-algo-1-t98o0 |       specific: {
# 2zgrtnfxpq-algo-1-t98o0 |         versions: 1
# 2zgrtnfxpq-algo-1-t98o0 |       }
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |   }
# 2zgrtnfxpq-algo-1-t98o0 | }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:tensorflow version info:
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.387082: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.387221: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2zgrtnfxpq-algo-1-t98o0 | TensorFlow ModelServer: 2.6.0-rc2+dev.sha.dca3641
# 2zgrtnfxpq-algo-1-t98o0 | TensorFlow Library: 2.6.0
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:tensorflow serving command: tensorflow_model_server --port=9000 --rest_api_port=8501 --model_config_file=/sagemaker/model-config.cfg --max_num_load_retries=0
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:started tensorflow serving (pid: 17)
# 2zgrtnfxpq-algo-1-t98o0 | INFO:tfs_utils:Trying to connect with model server: http://localhost:8501/v1/models/model
# 2zgrtnfxpq-algo-1-t98o0 | WARNING:urllib3.connectionpool:Retrying (Retry(total=8, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2fbfb72fa0>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.943431: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.943550: W external/org_tensorflow/tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.945820: I tensorflow_serving/model_servers/server_core.cc:465] Adding/updating models.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:39.945860: I tensorflow_serving/model_servers/server_core.cc:591]  (Re-)adding model: model
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.046239: I tensorflow_serving/util/retrier.cc:46] Retrying of Reserving resources for servable: {name: model version: 1} exhausted max_num_retries: 0
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.046312: I tensorflow_serving/core/basic_manager.cc:740] Successfully reserved resources to load servable {name: model version: 1}
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.046328: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.046349: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.046407: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:38] Reading SavedModel from: /opt/ml/model/000000001
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.048641: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:90] Reading meta graph with tags { serve }
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.048698: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /opt/ml/model/000000001
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.048825: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# 2zgrtnfxpq-algo-1-t98o0 | To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.049930: I external/org_tensorflow/tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.108908: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:211] Restoring SavedModel bundle.
# 2zgrtnfxpq-algo-1-t98o0 | WARNING:urllib3.connectionpool:Retrying (Retry(total=7, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2fbfb98220>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.176244: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:195] Running initialization op on SavedModel bundle at path: /opt/ml/model/000000001
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.183060: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:283] SavedModel load for tags { serve }; Status: success: OK. Took 136647 microseconds.
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.183776: I tensorflow_serving/servables/tensorflow/saved_model_warmup_util.cc:59] No warmup data file found at /opt/ml/model/000000001/assets.extra/tf_serving_warmup_requests
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.184291: I tensorflow_serving/util/retrier.cc:46] Retrying of Loading servable: {name: model version: 1} exhausted max_num_retries: 0
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.184312: I tensorflow_serving/core/loader_harness.cc:87] Successfully loaded servable version {name: model version: 1}
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.186012: I tensorflow_serving/model_servers/server_core.cc:486] Finished adding/updating models
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.186085: I tensorflow_serving/model_servers/server.cc:133] Using InsecureServerCredentials
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.186108: I tensorflow_serving/model_servers/server.cc:383] Profiler service is enabled
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.187851: I tensorflow_serving/model_servers/server.cc:409] Running gRPC ModelServer at 0.0.0.0:9000 ...
# 2zgrtnfxpq-algo-1-t98o0 | [warn] getaddrinfo: address family for nodename not supported
# 2zgrtnfxpq-algo-1-t98o0 | 2022-08-02 14:37:40.188853: I tensorflow_serving/model_servers/server.cc:430] Exporting HTTP/REST API at:localhost:8501 ...
# 2zgrtnfxpq-algo-1-t98o0 | [evhttp_server.cc : 245] NET_LOG: Entering the event loop ...
# 2zgrtnfxpq-algo-1-t98o0 | WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2fbfb98430>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2zgrtnfxpq-algo-1-t98o0 | INFO:tfs_utils:<Response [200]>
# 2zgrtnfxpq-algo-1-t98o0 | INFO:tfs_utils:model: http://localhost:8501/v1/models/model is available now
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:nginx config:
# 2zgrtnfxpq-algo-1-t98o0 | load_module modules/ngx_http_js_module.so;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | worker_processes auto;
# 2zgrtnfxpq-algo-1-t98o0 | daemon off;
# 2zgrtnfxpq-algo-1-t98o0 | pid /tmp/nginx.pid;
# 2zgrtnfxpq-algo-1-t98o0 | error_log  /dev/stderr error;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | worker_rlimit_nofile 4096;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | events {
# 2zgrtnfxpq-algo-1-t98o0 |   worker_connections 2048;
# 2zgrtnfxpq-algo-1-t98o0 | }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | http {
# 2zgrtnfxpq-algo-1-t98o0 |   include /etc/nginx/mime.types;
# 2zgrtnfxpq-algo-1-t98o0 |   default_type application/json;
# 2zgrtnfxpq-algo-1-t98o0 |   access_log /dev/stdout combined;
# 2zgrtnfxpq-algo-1-t98o0 |   js_include tensorflow-serving.js;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |   upstream tfs_upstream {
# 2zgrtnfxpq-algo-1-t98o0 |     server localhost:8501;
# 2zgrtnfxpq-algo-1-t98o0 |   }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |   upstream gunicorn_upstream {
# 2zgrtnfxpq-algo-1-t98o0 |     server unix:/tmp/gunicorn.sock fail_timeout=1;
# 2zgrtnfxpq-algo-1-t98o0 |   }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |   server {
# 2zgrtnfxpq-algo-1-t98o0 |     listen 8080 deferred;
# 2zgrtnfxpq-algo-1-t98o0 |     client_max_body_size 0;
# 2zgrtnfxpq-algo-1-t98o0 |     client_body_buffer_size 100m;
# 2zgrtnfxpq-algo-1-t98o0 |     subrequest_output_buffer_size 100m;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     set $tfs_version 2.6;
# 2zgrtnfxpq-algo-1-t98o0 |     set $default_tfs_model model;
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     location /tfs {
# 2zgrtnfxpq-algo-1-t98o0 |         rewrite ^/tfs/(.*) /$1  break;
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_redirect off;
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_pass_request_headers off;
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_set_header Content-Type 'application/json';
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_set_header Accept 'application/json';
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_pass http://tfs_upstream;
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     location /ping {
# 2zgrtnfxpq-algo-1-t98o0 |         js_content ping;
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     location /invocations {
# 2zgrtnfxpq-algo-1-t98o0 |         js_content invocations;
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     location /models {
# 2zgrtnfxpq-algo-1-t98o0 |         proxy_pass http://gunicorn_upstream/models;
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     location / {
# 2zgrtnfxpq-algo-1-t98o0 |         return 404 '{"error": "Not Found"}';
# 2zgrtnfxpq-algo-1-t98o0 |     }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |     keepalive_timeout 3;
# 2zgrtnfxpq-algo-1-t98o0 |   }
# 2zgrtnfxpq-algo-1-t98o0 | }
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 |
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:nginx version info:
# 2zgrtnfxpq-algo-1-t98o0 | nginx version: nginx/1.20.1
# 2zgrtnfxpq-algo-1-t98o0 | built by gcc 9.3.0 (Ubuntu 9.3.0-10ubuntu2)
# 2zgrtnfxpq-algo-1-t98o0 | built with OpenSSL 1.1.1f  31 Mar 2020
# 2zgrtnfxpq-algo-1-t98o0 | TLS SNI support enabled
# 2zgrtnfxpq-algo-1-t98o0 | configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fdebug-prefix-map=/data/builder/debuild/nginx-1.20.1/debian/debuild-base/nginx-1.20.1=. -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# 2zgrtnfxpq-algo-1-t98o0 | INFO:__main__:started nginx (pid: 73)
# !2zgrtnfxpq-algo-1-t98o0 | 172.18.0.1 - - [02/Aug/2022:14:37:42 +0000] "GET /ping HTTP/1.1" 200 0 "-" "python-urllib3/1.26.8"

# %%
X_test[:5]
# Out:
# array([[5.8, 2.7, 4.1, 1. ],
#        [4.8, 3.4, 1.6, 0.2],
#        [6. , 2.2, 4. , 1. ],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.7, 2.5, 5.8, 1.8]])

# %%
predictor.predict(X_test[:5])
# Out:
# {'predictions': [[0.0159433, 0.863972843, 0.120083801],
#   [0.987494886, 0.0124852769, 1.99404385e-05],
#   [0.00683279242, 0.843511641, 0.149655521],
#   [9.16040372e-05, 0.399594814, 0.600313604],
#   [9.18628e-06, 0.234145746, 0.76584512]]}
# 2zgrtnfxpq-algo-1-t98o0 | 172.18.0.1 - - [02/Aug/2022:14:37:46 +0000] "POST /invocations HTTP/1.1" 200 236 "-" "python-urllib3/1.26.8"

# %%
predictor.delete_endpoint()
# Out:
# Gracefully stopping... (press Ctrl+C again to force)
